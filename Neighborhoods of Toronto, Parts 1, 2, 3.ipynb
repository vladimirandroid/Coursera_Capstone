# %% [markdown]
# # Part1: creating dataframe from wiki page

# %%
import requests
import lxml.html as lh
import pandas as pd
import numpy as np

# %% [markdown]
# Load page and parse it into <tr> elements. Check that all rows have 3 columns.

# %%
url='https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
page = requests.get(url)
doc = lh.fromstring(page.content)

tr_elements = doc.xpath('//table')[0].xpath(".//tr")

# check number of columns:
[len(T) for T in tr_elements if len(T)!=3]
# Out:
# []

# %% [markdown]
# Now, lets fetch headers from tr_elements. For that lets take the first row:

# %%
headers = [T.text_content() for T in tr_elements[0]]
headers
# Out:
# ['Postal Code\n', 'Borough\n', 'Neighborhood\n']

# %% [markdown]
# Lets remove useless \n

# %%
headers = [T.replace("\n", "") for T in headers]
headers
# Out:
# ['Postal Code', 'Borough', 'Neighborhood']

# %% [markdown]
# Create list of columns with names and empty data

# %%
columns = [(title, []) for title in headers]
columns
# Out:
# [('Postal Code', []), ('Borough', []), ('Neighborhood', [])]

# %% [markdown]
# Add data to columns and remove useless \n from data

# %%
for r in tr_elements[1:]:
    for c in range(3):
        column = columns[c]
        column[1].append(r[c].text_content().replace("\n", ""))

# %% [markdown]
# Create Dict for creating pandas dataframe

# %%
d = {title: col for (title, col) in columns}

# %% [markdown]
# Create dataframe

# %%
df = pd.DataFrame(d)
df.shape
# Out:
# (180, 3)

# %% [markdown]
# Take DF without Not Assigned borough

# %%
df = df[df["Borough"]!="Not assigned"]
df.tail()
# Out:
#     Postal Code           Borough  \
# 160         M8X         Etobicoke
# 165         M4Y  Downtown Toronto
# 168         M7Y      East Toronto
# 169         M8Y         Etobicoke
# 178         M8Z         Etobicoke
#
#                                           Neighborhood
# 160      The Kingsway, Montgomery Road, Old Mill North
# 165                               Church and Wellesley
# 168  Business reply mail Processing Centre, South C...
# 169  Old Mill South, King's Mill Park, Sunnylea, Hu...
# 178  Mimico NW, The Queensway West, South of Bloor,...

# %% [markdown]
# Lets find empty Neighborhood now:

# %%
rows_empty_neighborhood = df["Neighborhood"] == ""
df[rows_empty_neighborhood]
# Out:
# Empty DataFrame
# Columns: [Postal Code, Borough, Neighborhood]
# Index: []

# %% [markdown]
# No such rows.
#
# So, here is the final shape:

# %%
df.shape
# Out:
# (103, 3)

# %% [markdown]
# # Part2: Geocoding

# %% [markdown]
# Read geo data from csv into dataframe:

# %%
geo_df = pd.read_csv("http://cocl.us/Geospatial_data")

# %% [markdown]
# Take a look at geo dataframe:

# %%
geo_df.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %% [markdown]
# Sort neighborhood and geo dataframes by postal code

# %%
geo_df.sort_values(by="Postal Code", inplace=True)
df.sort_values(by="Postal Code", inplace=True)

# %% [markdown]
# Check sizes of both dataframes:

# %%
print(geo_df.shape)
print(df.shape)
# Out:
# (103, 3)
# (103, 3)

# %% [markdown]
# Yehoo! Sizes are the same!
# Now just copy two columns to neighborhood dataframe:

# %%
df["Latitude"] = geo_df["Latitude"].values
df["Longitude"] = geo_df["Longitude"].values

df.head()
# Out:
#    Postal Code      Borough                            Neighborhood  \
# 9          M1B  Scarborough                          Malvern, Rouge
# 18         M1C  Scarborough  Rouge Hill, Port Union, Highland Creek
# 27         M1E  Scarborough       Guildwood, Morningside, West Hill
# 36         M1G  Scarborough                                  Woburn
# 45         M1H  Scarborough                               Cedarbrae
#
#      Latitude  Longitude
# 9   43.806686 -79.194353
# 18  43.784535 -79.160497
# 27  43.763573 -79.188711
# 36  43.770992 -79.216917
# 45  43.773136 -79.239476

# %% [markdown]
# # Part3: explore and cluster

# %% [markdown]
# Let's look at map of Toronto neiborhoods.
# First let's get Toronto coordinates:

# %%
from geopy.geocoders import Nominatim

address = 'Toronto, Canada'

geolocator = Nominatim(user_agent="toronto_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto are 43.6534817, -79.3839347.

# %%
# !pip install folium
# Out:
# Requirement already satisfied: folium in /opt/conda/envs/Python36/lib/python3.6/site-packages (0.11.0)
# Requirement already satisfied: requests in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (2.21.0)
# Requirement already satisfied: branca>=0.3.0 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (0.4.1)
# Requirement already satisfied: numpy in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (1.15.4)
# Requirement already satisfied: jinja2>=2.9 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (2.10)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (1.24.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (2020.4.5.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from jinja2>=2.9->folium) (1.1.0)

# %%
import folium

map = folium.Map(location=[latitude, longitude], zoom_start=10)

for lat, lng, borough, neighborhood in zip(df['Latitude'], df['Longitude'], df['Borough'], df['Neighborhood']):
    label = f"Borough: {borough}, Neighborhoods: {neighborhood}"
    label = folium.Popup(label)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        full=True,
        fill_color='red',
        fill_opacity=0.7,
    ).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Let's get Downtown Toronto only:

# %%
df_dt = df[df['Borough'] == 'Downtown Toronto']
df_dt.shape
# Out:
# (19, 5)

# %% [markdown]
# FourSquare initialization:

# %%
CLIENT_ID = '5MOABCDFEOHA5VYFDGM3B0RHLYXHLV3KLAFJA5UPVNMY5YYZ' # your Foursquare ID
CLIENT_SECRET = 'HGYEQ2WYC2EOTGVD100H3CQKDPDNBM3C2254AEGYSGJU4BLW' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

# %% [markdown]
# Create a function of getting venues by latitude and longitude for all neighborhoods:

# %%
import requests
import json

def venues_for_neighborhood(latitudes, longitudes, neighborhoods):
    venues_list = []
    for lat, lng, neib_name in zip(latitudes, longitudes, neighborhoods):
        url = f'http://api.foursquare.com/v2/venues/explore?client_id={CLIENT_ID}&client_secret={CLIENT_SECRET}&v={VERSION}&ll={lat},{lng}&radius=500&limit=100'
        result = requests.get(url).json()
        venues = result['response']['groups'][0]['items']
        
        venues_list.extend([(
            neib_name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in venues])
        
    nearby_venues = pd.DataFrame(venues_list)
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %% [markdown]
# Get data frame of venues for all neighborhoods:

# %%
downtown_venues = venues_for_neighborhood(neighborhoods=df_dt['Neighborhood'],
                                   latitudes=df_dt['Latitude'],
                                   longitudes=df_dt['Longitude']
                                  )

downtown_venues.shape
# Out:
# (1211, 7)

# %%
downtown_venues.head()
# Out:
#                   Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0                     Rosedale              43.679563              -79.377529
# 1                     Rosedale              43.679563              -79.377529
# 2                     Rosedale              43.679563              -79.377529
# 3                     Rosedale              43.679563              -79.377529
# 4  St. James Town, Cabbagetown              43.667967              -79.367675
#
#                   Venue  Venue Latitude  Venue Longitude Venue Category
# 0         Rosedale Park       43.682328       -79.378934     Playground
# 1          Whitney Park       43.682036       -79.373788           Park
# 2  Alex Murray Parkette       43.678300       -79.382773           Park
# 3        Milkman's Lane       43.676352       -79.373842          Trail
# 4           Cranberries       43.667843       -79.369407          Diner

# %% [markdown]
# Let's count number of venues in each neighborhood:

# %%
df_count = downtown_venues[['Neighborhood', 'Venue']].groupby('Neighborhood').count()
df_count
# Out:
#                                                     Venue
# Neighborhood
# Berczy Park                                            58
# CN Tower, King and Spadina, Railway Lands, Harb...     14
# Central Bay Street                                     62
# Christie                                               17
# Church and Wellesley                                   77
# Commerce Court, Victoria Hotel                        100
# First Canadian Place, Underground city                100
# Garden District, Ryerson                              100
# Harbourfront East, Union Station, Toronto Islands     100
# Kensington Market, Chinatown, Grange Park              58
# Queen's Park, Ontario Provincial Government            36
# Regent Park, Harbourfront                              45
# Richmond, Adelaide, King                               91
# Rosedale                                                4
# St. James Town                                         80
# St. James Town, Cabbagetown                            42
# Stn A PO Boxes                                         93
# Toronto Dominion Centre, Design Exchange              100
# University of Toronto, Harbord                         34

# %% [markdown]
# ### Let's investigate categories a bit
# Unique categories:

# %%
len(downtown_venues['Venue Category'].unique())
# Out:
# 208

# %% [markdown]
# Frequency of occurence of categories for each neighborhood:

# %%
dummies = pd.get_dummies(downtown_venues[['Venue Category']], prefix='', prefix_sep='')

#There is a category named Neighborhood. Rename this category to avoid conflict with original Neighborhood column:
dummies.columns = np.where(dummies.columns=='Neighborhood', 'Neighborhood_', dummies.columns)

#add original NEighborhood column:
dummies['Neighborhood'] = downtown_venues['Neighborhood']
fixed_columns = ['Neighborhood']
fixed_columns.extend(dummies.columns[0:-1].values)
dummies = dummies[fixed_columns]

# Here is the average frequency of all categories for each neighborhood:
frequency = dummies.groupby('Neighborhood').mean()
frequency.head()
# Out:
#                                                     Afghan Restaurant  \
# Neighborhood
# Berczy Park                                                  0.000000
# CN Tower, King and Spadina, Railway Lands, Harb...           0.000000
# Central Bay Street                                           0.000000
# Christie                                                     0.000000
# Church and Wellesley                                         0.012987
#
#                                                      Airport  \
# Neighborhood
# Berczy Park                                         0.000000
# CN Tower, King and Spadina, Railway Lands, Harb...  0.071429
# Central Bay Street                                  0.000000
# Christie                                            0.000000
# Church and Wellesley                                0.000000
#
#                                                     Airport Food Court  \
# Neighborhood
# Berczy Park                                                   0.000000
# CN Tower, King and Spadina, Railway Lands, Harb...            0.071429
# Central Bay Street                                            0.000000
# Christie                                                      0.000000
# Church and Wellesley                                          0.000000
#
#                                                     Airport Lounge  \
# Neighborhood
# Berczy Park                                               0.000000
# CN Tower, King and Spadina, Railway Lands, Harb...        0.142857
# Central Bay Street                                        0.000000
# Christie                                                  0.000000
# Church and Wellesley                                      0.000000
#
#                                                     Airport Service  \
# Neighborhood
# Berczy Park                                                0.000000
# CN Tower, King and Spadina, Railway Lands, Harb...         0.142857
# Central Bay Street                                         0.000000
# Christie                                                   0.000000
# Church and Wellesley                                       0.000000
#
#                                                     Airport Terminal  \
# Neighborhood
# Berczy Park                                                 0.000000
# CN Tower, King and Spadina, Railway Lands, Harb...          0.142857
# Central Bay Street                                          0.000000
# Christie                                                    0.000000
# Church and Wellesley                                        0.000000
#
#                                                     American Restaurant  \
# Neighborhood
# Berczy Park                                                    0.000000
# CN Tower, King and Spadina, Railway Lands, Harb...             0.000000
# Central Bay Street                                             0.000000
# Christie                                                       0.000000
# Church and Wellesley                                           0.012987
#
#                                                     Antique Shop  Aquarium  \
# Neighborhood
# Berczy Park                                                  0.0       0.0
# CN Tower, King and Spadina, Railway Lands, Harb...           0.0       0.0
# Central Bay Street                                           0.0       0.0
# Christie                                                     0.0       0.0
# Church and Wellesley                                         0.0       0.0
#
#                                                     Art Gallery  ...  \
# Neighborhood                                                     ...
# Berczy Park                                            0.017241  ...
# CN Tower, King and Spadina, Railway Lands, Harb...     0.000000  ...
# Central Bay Street                                     0.000000  ...
# Christie                                               0.000000  ...
# Church and Wellesley                                   0.000000  ...
#
#                                                     Theme Restaurant  Trail  \
# Neighborhood
# Berczy Park                                                 0.000000    0.0
# CN Tower, King and Spadina, Railway Lands, Harb...          0.000000    0.0
# Central Bay Street                                          0.000000    0.0
# Christie                                                    0.000000    0.0
# Church and Wellesley                                        0.012987    0.0
#
#                                                     Train Station  \
# Neighborhood
# Berczy Park                                                   0.0
# CN Tower, King and Spadina, Railway Lands, Harb...            0.0
# Central Bay Street                                            0.0
# Christie                                                      0.0
# Church and Wellesley                                          0.0
#
#                                                     Vegetarian / Vegan Restaurant  \
# Neighborhood
# Berczy Park                                                              0.017241
# CN Tower, King and Spadina, Railway Lands, Harb...                       0.000000
# Central Bay Street                                                       0.016129
# Christie                                                                 0.000000
# Church and Wellesley                                                     0.000000
#
#                                                     Video Game Store  \
# Neighborhood
# Berczy Park                                                      0.0
# CN Tower, King and Spadina, Railway Lands, Harb...               0.0
# Central Bay Street                                               0.0
# Christie                                                         0.0
# Church and Wellesley                                             0.0
#
#                                                     Vietnamese Restaurant  \
# Neighborhood
# Berczy Park                                                           0.0
# CN Tower, King and Spadina, Railway Lands, Harb...                    0.0
# Central Bay Street                                                    0.0
# Christie                                                              0.0
# Church and Wellesley                                                  0.0
#
#                                                     Wine Bar  Wings Joint  \
# Neighborhood
# Berczy Park                                         0.000000     0.000000
# CN Tower, King and Spadina, Railway Lands, Harb...  0.000000     0.000000
# Central Bay Street                                  0.016129     0.000000
# Christie                                            0.000000     0.000000
# Church and Wellesley                                0.000000     0.012987
#
#                                                     Women's Store  Yoga Studio
# Neighborhood
# Berczy Park                                                   0.0     0.000000
# CN Tower, King and Spadina, Railway Lands, Harb...            0.0     0.000000
# Central Bay Street                                            0.0     0.016129
# Christie                                                      0.0     0.000000
# Church and Wellesley                                          0.0     0.025974
#
# [5 rows x 208 columns]

# %% [markdown]
# Let's take a look at top 5 categories for each neighborhood:

# %%
t = frequency.copy()
t.reset_index(inplace=True)

for neighborhood in t['Neighborhood']:
    temp = t[t['Neighborhood']==neighborhood].T.reset_index()
    temp = temp.iloc[1:]
    temp.columns = ['Category', 'Frequency']
    temp['Frequency'] = temp['Frequency'].astype(float)
    temp.sort_values('Frequency', inplace=True, ascending=False)
    temp.reset_index(drop=True, inplace=True)
    print(f'\nNeighborhood: {neighborhood}:')
    #set index for better printing
#     temp.set_index('Category', inplace=True)
    print(temp.head())
# Out:
# Neighborhood: Berczy Park:
#        Category  Frequency
# 0   Coffee Shop   0.068966
# 1  Cocktail Bar   0.051724
# 2          Café   0.034483
# 3   Cheese Shop   0.034483
# 4        Bakery   0.034483
#
# Neighborhood: CN Tower, King and Spadina, Railway Lands, Harbourfront West, Bathurst Quay, South Niagara, Island airport:
#            Category  Frequency
# 0    Airport Lounge   0.142857
# 1   Airport Service   0.142857
# 2  Airport Terminal   0.142857
# 3   Harbor / Marina   0.071429
# 4           Airport   0.071429
#
# Neighborhood: Central Bay Street:
#              Category  Frequency
# 0         Coffee Shop   0.177419
# 1      Sandwich Place   0.064516
# 2  Italian Restaurant   0.064516
# 3                Café   0.048387
# 4        Burger Joint   0.032258
#
# Neighborhood: Christie:
#         Category  Frequency
# 0  Grocery Store   0.235294
# 1           Café   0.176471
# 2           Park   0.117647
# 3     Baby Store   0.058824
# 4     Restaurant   0.058824
#
# Neighborhood: Church and Wellesley:
#               Category  Frequency
# 0          Coffee Shop   0.077922
# 1  Japanese Restaurant   0.064935
# 2     Sushi Restaurant   0.051948
# 3              Gay Bar   0.038961
# 4           Restaurant   0.038961
#
# Neighborhood: Commerce Court, Victoria Hotel:
#       Category  Frequency
# 0  Coffee Shop       0.11
# 1         Café       0.07
# 2   Restaurant       0.07
# 3        Hotel       0.05
# 4          Gym       0.04
#
# Neighborhood: First Canadian Place, Underground city:
#               Category  Frequency
# 0          Coffee Shop       0.10
# 1                 Café       0.08
# 2                Hotel       0.04
# 3                  Gym       0.04
# 4  Japanese Restaurant       0.04
#
# Neighborhood: Garden District, Ryerson:
#           Category  Frequency
# 0   Clothing Store       0.09
# 1      Coffee Shop       0.08
# 2   Cosmetics Shop       0.03
# 3       Restaurant       0.03
# 4  Bubble Tea Shop       0.03
#
# Neighborhood: Harbourfront East, Union Station, Toronto Islands:
#          Category  Frequency
# 0     Coffee Shop       0.13
# 1        Aquarium       0.05
# 2           Hotel       0.04
# 3            Café       0.04
# 4  Scenic Lookout       0.03
#
# Neighborhood: Kensington Market, Chinatown, Grange Park:
#                 Category  Frequency
# 0                   Café   0.086207
# 1            Coffee Shop   0.068966
# 2     Mexican Restaurant   0.051724
# 3           Dessert Shop   0.051724
# 4  Vietnamese Restaurant   0.051724
#
# Neighborhood: Queen's Park, Ontario Provincial Government:
#         Category  Frequency
# 0    Coffee Shop   0.222222
# 1    Yoga Studio   0.027778
# 2  Burrito Place   0.027778
# 3       Beer Bar   0.027778
# 4           Park   0.027778
#
# Neighborhood: Regent Park, Harbourfront:
#          Category  Frequency
# 0     Coffee Shop   0.155556
# 1             Pub   0.066667
# 2          Bakery   0.066667
# 3            Park   0.066667
# 4  Breakfast Spot   0.044444
#
# Neighborhood: Richmond, Adelaide, King:
#          Category  Frequency
# 0     Coffee Shop   0.098901
# 1            Café   0.054945
# 2      Restaurant   0.043956
# 3  Clothing Store   0.032967
# 4           Hotel   0.032967
#
# Neighborhood: Rosedale:
#             Category  Frequency
# 0               Park       0.50
# 1         Playground       0.25
# 2              Trail       0.25
# 3      Movie Theater       0.00
# 4  Martial Arts Dojo       0.00
#
# Neighborhood: St. James Town:
#        Category  Frequency
# 0          Café     0.0625
# 1   Coffee Shop     0.0625
# 2  Cocktail Bar     0.0500
# 3    Restaurant     0.0375
# 4     Gastropub     0.0375
#
# Neighborhood: St. James Town, Cabbagetown:
#       Category  Frequency
# 0  Coffee Shop   0.071429
# 1       Bakery   0.047619
# 2         Café   0.047619
# 3          Pub   0.047619
# 4   Restaurant   0.047619
#
# Neighborhood: Stn A PO Boxes:
#               Category  Frequency
# 0          Coffee Shop   0.096774
# 1                 Café   0.043011
# 2  Japanese Restaurant   0.032258
# 3   Italian Restaurant   0.032258
# 4         Cocktail Bar   0.032258
#
# Neighborhood: Toronto Dominion Centre, Design Exchange:
#              Category  Frequency
# 0         Coffee Shop       0.10
# 1                Café       0.06
# 2               Hotel       0.06
# 3          Restaurant       0.04
# 4  Italian Restaurant       0.03
#
# Neighborhood: University of Toronto, Harbord:
#               Category  Frequency
# 0                 Café   0.147059
# 1                  Bar   0.058824
# 2           Restaurant   0.058824
# 3   Italian Restaurant   0.058824
# 4  Japanese Restaurant   0.058824

# %% [markdown]
# Form a DataFrame of 10 most common venue categories for each neighborhood:

# %%
def ten_most_common_categories(row):
    row_categories = row.iloc[1:]
    row_categories = row_categories.sort_values(ascending=False)
    return row_categories.index.values[0:10]

indicators = ['st', 'nd', 'rd']
columns = ['Neighborhood']
for ind in np.arange(10):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

df_most_ten = pd.DataFrame(columns=columns)
df_most_ten['Neighborhood'] = t['Neighborhood']

for row in np.arange(frequency.shape[0]):
    df_most_ten.iloc[row, 1:] = ten_most_common_categories(t.iloc[row])

# %% [markdown]
# ### Cluster neighborhoods

# %%
from sklearn.cluster import KMeans

# %%
clusters = 5
df_without_neighborhood = t.iloc[:, 1:]
df_without_neighborhood.head()

kmeans = KMeans(n_clusters=clusters, random_state=0).fit(df_without_neighborhood)
kmeans.labels_[0:10]

#let's look on top 10 categories and clusters together:
df_most_ten_with_clusters = df_most_ten.copy()
df_most_ten_with_clusters.insert(0, 'Cluster', kmeans.labels_)

fixed_columns = list(df_most_ten_with_clusters.columns)
# print(fixed_columns)
fixed_columns = ['Postal Code', 'Borough', 'Latitude', 'Longitude'] + fixed_columns
# print(fixed_columns)

df_most_ten_with_clusters = df_most_ten_with_clusters.join(df.set_index('Neighborhood'), on='Neighborhood')
df_most_ten_with_clusters = df_most_ten_with_clusters[fixed_columns]
df_most_ten_with_clusters.head()
# Out:
#   Postal Code           Borough   Latitude  Longitude  Cluster  \
# 0         M5E  Downtown Toronto  43.644771 -79.373306        1
# 1         M5V  Downtown Toronto  43.628947 -79.394420        0
# 2         M5G  Downtown Toronto  43.657952 -79.387383        4
# 3         M6G  Downtown Toronto  43.669542 -79.422564        3
# 4         M4Y  Downtown Toronto  43.665860 -79.383160        1
#
#                                         Neighborhood 1st Most Common Venue  \
# 0                                        Berczy Park           Coffee Shop
# 1  CN Tower, King and Spadina, Railway Lands, Har...        Airport Lounge
# 2                                 Central Bay Street           Coffee Shop
# 3                                           Christie         Grocery Store
# 4                               Church and Wellesley           Coffee Shop
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0          Cocktail Bar                Bakery                   Pub
# 1       Airport Service      Airport Terminal         Boat or Ferry
# 2        Sandwich Place    Italian Restaurant                  Café
# 3                  Café                  Park           Candy Store
# 4   Japanese Restaurant      Sushi Restaurant            Restaurant
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0           Cheese Shop            Restaurant              Beer Bar
# 1              Boutique      Sculpture Garden                 Plane
# 2          Burger Joint   Japanese Restaurant           Salad Place
# 3    Italian Restaurant                 Diner            Restaurant
# 4               Gay Bar                  Café                   Pub
#
#   8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0    Seafood Restaurant                  Café           Gourmet Shop
# 1                   Bar       Harbor / Marina     Airport Food Court
# 2       Bubble Tea Shop                  Park                  Hotel
# 3            Baby Store    Athletics & Sports              Nightclub
# 4            Smoke Shop                 Hotel            Yoga Studio

# %% [markdown]
# Visualize resulting clusters:

# %%
import matplotlib.cm as cm
import matplotlib.colors as colors

# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(clusters)
ys = [i + x + (i*x)**2 for i in range(clusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(df_most_ten_with_clusters['Latitude'], df_most_ten_with_clusters['Longitude'], df_most_ten_with_clusters['Neighborhood'], df_most_ten_with_clusters['Cluster']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### let's take a look to clusters content:

# %%
df_most_ten_with_clusters.loc[df_most_ten_with_clusters['Cluster'] == 0, df_most_ten_with_clusters.columns[[1] + list(range(5, df_most_ten_with_clusters.shape[1]))]]
# Out:
#             Borough                                       Neighborhood  \
# 1  Downtown Toronto  CN Tower, King and Spadina, Railway Lands, Har...
#
#   1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 1        Airport Lounge       Airport Service      Airport Terminal
#
#   4th Most Common Venue 5th Most Common Venue 6th Most Common Venue  \
# 1         Boat or Ferry              Boutique      Sculpture Garden
#
#   7th Most Common Venue 8th Most Common Venue 9th Most Common Venue  \
# 1                 Plane                   Bar       Harbor / Marina
#
#   10th Most Common Venue
# 1     Airport Food Court

# %%
df_most_ten_with_clusters.loc[df_most_ten_with_clusters['Cluster'] == 1, df_most_ten_with_clusters.columns[[1] + list(range(5, df_most_ten_with_clusters.shape[1]))]]
# Out:
#              Borough                                       Neighborhood  \
# 0   Downtown Toronto                                        Berczy Park
# 4   Downtown Toronto                               Church and Wellesley
# 5   Downtown Toronto                     Commerce Court, Victoria Hotel
# 6   Downtown Toronto             First Canadian Place, Underground city
# 7   Downtown Toronto                           Garden District, Ryerson
# 8   Downtown Toronto  Harbourfront East, Union Station, Toronto Islands
# 9   Downtown Toronto          Kensington Market, Chinatown, Grange Park
# 12  Downtown Toronto                           Richmond, Adelaide, King
# 14  Downtown Toronto                                     St. James Town
# 15  Downtown Toronto                        St. James Town, Cabbagetown
# 16  Downtown Toronto                                     Stn A PO Boxes
# 17  Downtown Toronto           Toronto Dominion Centre, Design Exchange
# 18  Downtown Toronto                     University of Toronto, Harbord
#
#    1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 0            Coffee Shop          Cocktail Bar                Bakery
# 4            Coffee Shop   Japanese Restaurant      Sushi Restaurant
# 5            Coffee Shop                  Café            Restaurant
# 6            Coffee Shop                  Café                 Hotel
# 7         Clothing Store           Coffee Shop                  Café
# 8            Coffee Shop              Aquarium                 Hotel
# 9                   Café           Coffee Shop          Dessert Shop
# 12           Coffee Shop                  Café            Restaurant
# 14           Coffee Shop                  Café          Cocktail Bar
# 15           Coffee Shop    Chinese Restaurant            Restaurant
# 16           Coffee Shop                  Café                   Pub
# 17           Coffee Shop                  Café                 Hotel
# 18                  Café   Japanese Restaurant                   Bar
#
#    4th Most Common Venue  5th Most Common Venue      6th Most Common Venue  \
# 0                    Pub            Cheese Shop                 Restaurant
# 4             Restaurant                Gay Bar                       Café
# 5                  Hotel    American Restaurant                        Gym
# 6             Restaurant    Japanese Restaurant                        Gym
# 7     Italian Restaurant         Cosmetics Shop  Middle Eastern Restaurant
# 8                   Café         Scenic Lookout                    Brewery
# 9                 Bakery  Vietnamese Restaurant         Mexican Restaurant
# 12                   Gym         Clothing Store              Deli / Bodega
# 14             Gastropub    American Restaurant                 Restaurant
# 15                   Pub                   Café         Italian Restaurant
# 16            Restaurant               Beer Bar         Seafood Restaurant
# 17            Restaurant            Salad Place         Seafood Restaurant
# 18    Italian Restaurant              Bookstore                     Bakery
#
#    7th Most Common Venue 8th Most Common Venue 9th Most Common Venue  \
# 0               Beer Bar    Seafood Restaurant                  Café
# 4                    Pub            Smoke Shop                 Hotel
# 5          Deli / Bodega   Japanese Restaurant    Italian Restaurant
# 6       Asian Restaurant    Seafood Restaurant            Steakhouse
# 7        Bubble Tea Shop   Japanese Restaurant            Restaurant
# 8    Sporting Goods Shop            Restaurant   Fried Chicken Joint
# 9            Gaming Cafe         Grocery Store                   Bar
# 12       Thai Restaurant                 Hotel   American Restaurant
# 14              Beer Bar                   Gym                 Hotel
# 15           Pizza Place                Bakery               Butcher
# 16          Cocktail Bar   Japanese Restaurant    Italian Restaurant
# 17   American Restaurant   Japanese Restaurant    Italian Restaurant
# 18            Restaurant        Sandwich Place              Beer Bar
#
#            10th Most Common Venue
# 0                    Gourmet Shop
# 4                     Yoga Studio
# 5              Seafood Restaurant
# 6                   Deli / Bodega
# 7                           Diner
# 8              Italian Restaurant
# 9   Vegetarian / Vegan Restaurant
# 12                 Cosmetics Shop
# 14             Italian Restaurant
# 15                     Playground
# 16                    Art Gallery
# 17               Sushi Restaurant
# 18                     Beer Store

# %%
df_most_ten_with_clusters.loc[df_most_ten_with_clusters['Cluster'] == 2, df_most_ten_with_clusters.columns[[1] + list(range(5, df_most_ten_with_clusters.shape[1]))]]
# Out:
#              Borough Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 13  Downtown Toronto     Rosedale                  Park            Playground
#
#    3rd Most Common Venue 4th Most Common Venue        5th Most Common Venue  \
# 13                 Trail          Dance Studio  Eastern European Restaurant
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 13            Donut Shop      Doner Restaurant               Dog Run
#
#    9th Most Common Venue 10th Most Common Venue
# 13   Distribution Center         Discount Store

# %%
df_most_ten_with_clusters.loc[df_most_ten_with_clusters['Cluster'] == 3, df_most_ten_with_clusters.columns[[1] + list(range(5, df_most_ten_with_clusters.shape[1]))]]
# Out:
#             Borough Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 3  Downtown Toronto     Christie         Grocery Store                  Café
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 3                  Park           Candy Store    Italian Restaurant
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 3                 Diner            Restaurant            Baby Store
#
#   9th Most Common Venue 10th Most Common Venue
# 3    Athletics & Sports              Nightclub

# %%
df_most_ten_with_clusters.loc[df_most_ten_with_clusters['Cluster'] == 4, df_most_ten_with_clusters.columns[[1] + list(range(5, df_most_ten_with_clusters.shape[1]))]]
# Out:
#              Borough                                 Neighborhood  \
# 2   Downtown Toronto                           Central Bay Street
# 10  Downtown Toronto  Queen's Park, Ontario Provincial Government
# 11  Downtown Toronto                    Regent Park, Harbourfront
#
#    1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 2            Coffee Shop        Sandwich Place    Italian Restaurant
# 10           Coffee Shop            Hobby Shop            Restaurant
# 11           Coffee Shop                   Pub                Bakery
#
#    4th Most Common Venue 5th Most Common Venue 6th Most Common Venue  \
# 2                   Café          Burger Joint   Japanese Restaurant
# 10                  Bank                   Bar                 Diner
# 11                  Park        Breakfast Spot                  Café
#
#    7th Most Common Venue 8th Most Common Venue 9th Most Common Venue  \
# 2            Salad Place       Bubble Tea Shop                  Park
# 10         Smoothie Shop        Discount Store                  Café
# 11               Theater           Yoga Studio        Farmers Market
#
#    10th Most Common Venue
# 2                   Hotel
# 10            Yoga Studio
# 11  Performing Arts Venue
